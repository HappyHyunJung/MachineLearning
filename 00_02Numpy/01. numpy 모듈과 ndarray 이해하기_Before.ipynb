# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3])
y = np.array([2, 4, 6])

print(x)
print(y)

plt.plot(x, y)
# Out:
# [1 2 3]
# [2 4 6]

# %%
x = np.array([1, 2, 3])
y = np.array([3, 6, 9])

print(x)
print(y)

plt.plot(x, y)
# Out:
# [1 2 3]
# [3 6 9]
